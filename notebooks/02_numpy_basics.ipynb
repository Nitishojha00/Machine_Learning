# %%
import numpy as np

# create array
a = np.array([10, 20, 30, 40, 50])

print("Array:", a)
print("Mean:", a.mean())
print("Sum:", a.sum())
print("Max:", a.max())
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Sum: 150
# Max: 50
