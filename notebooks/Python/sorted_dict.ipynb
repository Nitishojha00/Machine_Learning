# %%
from sortedcontainers import SortedDict

# a = SortedDict()
a = SortedDict(list)

a["c"] = 3
a["a"] = 1
a["b"] = 2

# print(a)
# print(a.get("b"))
# print(len(a))
# print(a.peekitem(-2))   access from backside 
v1,v2 = a.peekitem(-2)
print(v1)
# Out:
# b
